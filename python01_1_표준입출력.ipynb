# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```
#
# # Python 표준 입출력

# %% [markdown]
# ## 1. 표준 출력 : print()
# ### 아래와 같은 출력결과를 비교하여 코드를 작성하고 실행하여 보자.
# 3. end ='' 이용
# 4. ',' 이용
# 5. '+' 이용
# ---
# 1. Hello
# 2. World!
# 3. Hello World!
# 4. Hello  World!
# 5. Hello World!
#
# ---

# %%
# 표준 출력
print('Hello ', end='')
print("World!")

# 한줄 연결 출력
# Out:
# Hello World!

# %% [markdown]
# ###이스케이프 시퀀스(escape sequence)
# \와 특정 문자를 결합하여 문자를 표시해 주는 문자
# + \\ : \\
# + \’ : 작은 따옴표
# + \” : 큰 따옴표
# + \n : 개행(엔터)
# + \t : 탭

# %% [markdown]
# ##다음과 같이 출력해 보자.
#
# [입력]
# 이름을 입력하세요python
# [출력]
# hello, 'python'
# hello, "python"
# "Life is short, You need 'python' "

# %%
name=input('이름을 입력하세요')

print(f"hello, {name}")
print('hello, "python"')
print(f'"Life is short, You need \'{name}\' "')

## displaying single quotations

## displaying double quotations
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-4e27e56f7326> in <cell line: 1>()
# ----> 1 name=input('이름을 입력하세요')
#       2
#       3 print(f"hello, {name}")
#       4 print('hello, "python"')
#       5 print(f'"Life is short, You need \'{name}\' "')
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
name=input('이름을 입력하세요')
print(f"hello, {name}")
print('hello, "python"')
print(f'"Life is short, You need \'{name}\' "')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-6b22dacc8271> in <cell line: 1>()
# ----> 1 name=input('이름을 입력하세요')
#       2 print(f"hello, {name}")
#       3 print('hello, "python"')
#       4 print(f'"Life is short, You need \'{name}\' "')
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
print('Hello\tWorld!')
# Out:
# Hello	World!

# %% [markdown]
# ## 2.표준 입력 :input('메시지')
# + 문자열 입력
# + 정수 입력 : int() 함수로 형변환
# + 실수 입력 : float() 함수로 형변환

# %%
x = int(input())
print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-be09f7974407> in <cell line: 1>()
# ----> 1 x = int(input())
#       2 print(x)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
y = float(input('실수입력'))
print(y)

# %% [markdown]
# ---
# 2-1 해결문제) 두 정수를 입력 받아서 사칙연산을 수행하는 코드를 작성하시오.
#
# (입출력)
# 첫번째 정수 입력10
# 두번째 정수 입력3
# 10 + 3  =  13
# 10 - 3  =  7
# 10 x 3  =  30
# 10 / 3  =  3.3333333333333335
# 10 / 3  나눈 몫 :  3
# 10 / 3  나눈 나머지 :  1
#
# ---

# %%
x = int(input('첫번째 정수 입력'))
y = int(input('두번째 정수 입력'))

#연산 수행
print( x , '+' , y , ' = ', (x+y))
print(x , '-' , y , ' = ', (x-y))
print(x , 'x' , y , ' = ', (x*y))
print(x , '/' , y , ' = ', (x/y))
print(x , '/' , y , '나눈 몫', (x//y))
print(x , '/' , y , '나눈 나머지', (x%y))

# %% [markdown]
# ### f-string 사용 : Python 신규 버전(3.6 이상) 부터 제공되는 기능
# + 사용법 : f'문자열{변수}문자열'

# %% [markdown]
# 2-2.  두 정수를 입력 받아서 사칙연산을 수행하는 2-1을 f-string을 사용하여 출력하시오.
#
# ---
# (입출력)
# 첫번째 정수 입력10
# 두번째 정수 입력3
# 10 + 3  =  13
# 10 - 3  =  7
# 10 x 3  =  30
# 10 / 3  =  3.3333333333333335
# 10 / 3  나눈 몫 :  3
# 10 / 3  나눈 나머지 :  1
#
# ---

# %%
x = int(input('첫번째 정수 입력'))
y = int(input('두번째 정수 입력'))

#연산 수행
print(f"{x} + {y} = {(x+y)}")
print(f"{x} - {y} = {(x-y)}")
print(f"{x} x {y} = {(x*y)}")
print(f"{x} / {y} = {(x/y)}")
print(f"{x} / {y} 나눈 몫 : {(x//y)}")
print(f"{x} / {y} 나눈 나머지 : {(x%y)}")

# %% [markdown]
# # 변수
# + **어떤 값을 저장하는 공간**
#  - 어떤 데이터가 있을 때 그 데이터가 메모리 상에 위치하는 주소를 변수라는 곳에 저장해두고, 나중에 변수에 저장된 메모리 상의 주소에 가서 실제 값을 읽을 수 있는 것
# + **Python은 기본적으로 인터프리터(interpreter)를 통해 실행되는 스크립트 언어**
#  - 변수를 선언할 때 타입을 지정하지 않음
#  - 값을 할당하면 그때 동적으로 타입이 정해짐
#  - 타입이 다를 경우 형 변환을 해줘야 연산에 사용할 수 있음
# + **변수 명 규칙**
#  - 영문 문자와 숫자 사용 :  대소문자 구분
#  - 문자나 _(밑줄 문자)로 시작 : 숫자부터 시작하면 안 됨
#  - 특수 문자(+, -, *, /, $, @, &, % 등)는 사용할 수 없음
#  - python 키워드(if, for, while, and, or 등)는 사용할 수 없음
#
#
# 아래와 같이 실행하여 키워드를 출력해보자.
# import keyword
# print(keyword.kwlist)

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### 섭씨 온도를 입력받아서 화씨온도로 변환하는 코드를 작성하시오.
#   °F = °C × 1.8 + 32
#
#
# ---
#
#
# [입력]   섭씨온도 :30
# [출력]  화씨온도는 86.0입니다.

# %%
c = float(input("섭씨온도 :"))
f = 1.8 * c + 32
print(f'화씨온도는 {f}입니다.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-6240fa7ba312> in <cell line: 1>()
# ----> 1 c = float(input())
#       2 f = 1.8 * c + 32
#       3 print(f'화씨온도는 {f}입니다.')
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# ---
# 해결문제)
#
# BMI는 몸무게와 키를 이용하여 체지방율을 측정하는 지수이다. 자신의 몸무게와 키를 입력 받아 각각 변수 weight와 height에 저장하고 BMI지수를 계산해 본다. 단, 키는 cm로 입력 받아서 처리한다.(키와 몸무게는 소수점이 입력된다.)
# + BMI = 체중(kg) / (키(m) x키(m))
# [입력]
# weight(kg) : 70
# height(cm) : 170
# [출력]
# BMI :24.22
#
#
# ---

# %%
b = float(input("weight(kg) : "))
m = float(input("height(cm) : "))
print(f"BMI :{b / (m**2/10000)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-88fcd42d4442> in <cell line: 1>()
# ----> 1 b = float(input())
#       2 m = float(input())
#       3 print(f"BMI : {b / (m**2/10000)}")
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# ---
# 해결문제)
#
# 환율 계산기를 작성하시오.
# + 입력
#  - 1달러 환율 입력
#  - 원화입력
# + 출력
#  - 환전 달러
#
# [입력]
# 1$ 환율: 0.74
#
# 원화: 100000
# [출력]
# USD :74.0 $
#
# ---

# %%
d = float(input("1$ 환율: "))
w = float(input("원화: "))

print('USD :{:.1f} $'.format((d/1000)*w))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-df7b781f11ed> in <cell line: 1>()
# ----> 1 d = float(input("1$ 환율: "))
#       2 w = float(input("원화: "))
#       3
#       4 print('USD :{:.1f} $'.format((d/1000)*w))
#
# TypeError: 'str' object cannot be interpreted as an integer
