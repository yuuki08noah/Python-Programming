# %% [markdown]
# # Python의 대표적 모듈
# + matplotlib.pyplot : 시각화 모듈
# + numpy : 수치해석 모듈
# + pandas : 데이터 분석 모듈
# + requests : HTTP 요청/응답 모듈

# %% [markdown]
# # 데이터 시각화 모듈 : matplotlib.pyplot
# ##[모듈 불러오기] import matplotlib.pyplot as plt
# ##시각화 모듈을 사용한 그래프 그리기
# - 선 그래프: 시계열 데이터나 두 변수 간의 관계를 시각화.
# - 막대 그래프: 카테고리형 데이터를 비교.
# - 히스토그램: 데이터의 분포를 시각적으로 확인.
# - 산점도: 두 변수 간의 상관관계를 확인.
# - 파이 차트: 비율이나 구성 비중을 확인.
#
# ##plot함수 : 그래프를 그리는 함수
# ##-[사용법] plot(x축리스트, y축 리스트, **속성 )
# - 대표 속성 : linewidth, color, marker, linestyle,title, xlabel, ylabel, grid
# ##show : 그래프를 보여줌

# %% [markdown]
# ##[실습]1. 기온데이터를 이용하여 그래프를 작성해 보자.

# %%
#시각화 모듈
import matplotlib.pyplot as plt

#부산 3월 기온
temp = [10.8, 8.5, 8.7, 7.9, 5.1,
        8.1, 8.2, 10.4, 11, 9.9,
        7.8, 9.5, 11.6, 8.2, 7.7,
        6.6, 11.1, 12.2, 12.6, 10.4,
        13.7, 14.1, 12.6, 11.5, 13,
        14.5, 13.7, 9.4, 10.4, 11.6, 12.9]
        # x축을 순번, y축을 기온으로 하는 그래프 그리기

plt.plot(temp, color='red')
plt.show()

# %%
# # 나눔 글꼴 설치

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] =False
#1.런타임 -세션 다시 시작 ,모두 재실행
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %% [markdown]
# ## **선 옵션**
# + **색상**
#  - b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
# + **마커**
#  - o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)
# + **선스타일**
#  - \-(solid line), --(dashed line ), -. (dash-dot line), : (dotted line )

# %% [markdown]
# ## **그래프 크기 조절**
# + plt.figure()
#  - figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)

# %%
#그래프 크기 조절: 가로 세로를 튜플로
plt.figure(10, 6)

# %% [markdown]
# ##[실습]2. 실습1의 그래프에 그래프의 크기, 그래프의 제목, x라벨, y라벨, 선옵션을 설정하여 작성하시오.
# - 그래프의 크기 figsize=(10,6)
# - 그래프의 제목 : 3월 기온
# - x라벨 : 날짜
# - y라벨 : 기온
# - 선옵션 : 선색은 그린, 점선으로 표시

# %%
 # 정답을 작성하시오.
 #시각화 모듈
import matplotlib.pyplot as plt

#부산 3월 기온
temp = [10.8, 8.5, 8.7, 7.9, 5.1,
        8.1, 8.2, 10.4, 11, 9.9,
        7.8, 9.5, 11.6, 8.2, 7.7,
        6.6, 11.1, 12.2, 12.6, 10.4,
        13.7, 14.1, 12.6, 11.5, 13,
        14.5, 13.7, 9.4, 10.4, 11.6, 12.9]
plt.figure(figsize=(10, 6))
plt.title('3월 기온')
plt.xlabel('날짜')
plt.ylabel('기온')
plt.plot(temp, color='green', linestyle=':')
plt.show()

# %%
#그래프의 크기, 그래프의 제목, x라벨, y라벨, 선옵션을 설정하여 작성하시오.

 # 정답을 작성하시오.
 #시각화 모듈
import matplotlib.pyplot as plt

#부산 3월 기온
temp = [10.8, 8.5, 8.7, 7.9, 5.1,
        8.1, 8.2, 10.4, 11, 9.9,
        7.8, 9.5, 11.6, 8.2, 7.7,
        6.6, 11.1, 12.2, 12.6, 10.4,
        13.7, 14.1, 12.6, 11.5, 13,
        14.5, 13.7, 9.4, 10.4, 11.6, 12.9]
plt.figure(figsize=(10, 6))
plt.title('3월 기온')
plt.xlabel('날짜')
plt.ylabel('기온')
plt.plot(temp, color='green', linestyle=':')
plt.show()

# %% [markdown]
# # 그리드 (grid)
# + grid() 함수의 첫번째 파라미터를 True로 설정하면 그래프에 그리드 (grid)가 표시
# + alpha:  그리드의 투명도를 설정
#  - 0으로 설정하면 투명하게, 1은 불투명하게 표시
# + linestyle : 선의 스타일을 대쉬 (Dashed)로 설정
#
#
# # 수평 / 수직선 그리기
# + plt.axvline(x, color)
#  - 축을 가로지르는 세로 선 생성
# + plt.axhline(y, color)
#  - 축을 가로지르는 가로 선 생성
#
# # 글자 쓰기
# + plt.text(x, y, s, fontsize)
#  - 원하는 위치에 텍스트 생성

# %% [markdown]
# ##[실습]3. 실습2의 그래프에 그리드,가로축라인(빨강)을 추가 설정하여 작성하시오.

# %%
#그래프 크기 조절: 가로 세로를 튜플로
 # 정답을 작성하시오.
 #시각화 모듈
import matplotlib.pyplot as plt

#부산 3월 기온
temp = [10.8, 8.5, 8.7, 7.9, 5.1,
        8.1, 8.2, 10.4, 11, 9.9,
        7.8, 9.5, 11.6, 8.2, 7.7,
        6.6, 11.1, 12.2, 12.6, 10.4,
        13.7, 14.1, 12.6, 11.5, 13,
        14.5, 13.7, 9.4, 10.4, 11.6, 12.9]
plt.figure(figsize=(10, 6))
plt.title('3월 기온')
plt.xlabel('날짜')
plt.ylabel('기온')
plt.plot(temp, color='green', linestyle=':')
plt.grid(True, alpha=0.5, linestyle='--')
plt.axhline(7, color='blue', linestyle='--')
plt.axvline(15, color='violet', linestyle='--')
plt.show()

# %% [markdown]
# ##범례 위치 종류
# best(0), upper right(1), upper left(2), lower left(3), lower right(4), right(50, center left(6), center right(7), lower center(8), upper center(9), center(10)

# %% [markdown]
# ###[실습]4.실습3의 그래프를 두개의 그래프로 겹쳐서 그려보자.

# %%
#그래프 겹쳐 그리기 정답
#그래프 크기 조절: 가로 세로를 튜플로
 # 정답을 작성하시오.
 #시각화 모듈
import matplotlib.pyplot as plt

#부산 3월 기온
temp = [10.8, 8.5, 8.7, 7.9, 5.1,
        8.1, 8.2, 10.4, 11, 9.9,
        7.8, 9.5, 11.6, 8.2, 7.7,
        6.6, 11.1, 12.2, 12.6, 10.4,
        13.7, 14.1, 12.6, 11.5, 13,
        14.5, 13.7, 9.4, 10.4, 11.6, 12.9]
plt.plot(temp, 'g-', label='기본')
plt.legend(loc = 'best')
plt.plot(temp, 'b:', label='헬로', drawstyle='steps')

# %% [markdown]
# ###Numpy의 linspace함수
# [사용법] 변수 = np.linspace(시작,끝, 데이터개수)
# 데이터개수를 생략하면 랜덤하게 50개의 축 리스트 생성

# %% [markdown]
# #그래프 겹쳐 그리기
# plt.figure(figsize=(10,6))
# plt.plot(temp, 'g--', label='기본')
# plt.plot(temp, 'b-', drawstyle='steps-post', label='계단식')
# plt.legend(loc='best') #범례 설정
# plt.show()

# %% [markdown]
# ##[실습]5.Numpy의 linspace함수를 이용해 축 데이터를 생성해 그래프를 작성하시오.

# %%
#Numpy의 linspace함수를 이용해 축 데이터를 생성해 그래프를 작성하시오.

import numpy as np
import matplotlib.pyplot as plt
#linspace로 축 데이터 만들기

s1 = np.linspace(1, 10000, 10000)
s2 = np.log(s1)
plt.plot(s1, s2)
plt.show()

# %% [markdown]
# ##[실습]6. 사인(sin)함수 그래프 그리기

# %%
#Numpy의 linspace함수를 이용해 축 데이터를 생성 하여 사인(sin)함수 그래프 그리기
#linspace 함수를 이용하여 0부터 4파이 사이를 200개로 나눈 X값을 생성합니다. Y값은 사인함수를 사용하여 생성
x = np.linspace(0, 12*np.pi, 500)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# ##한 화면에 그래프를 여러개 그리는 방법
# - subplot
#
# - add_subplot
#
# - subplot2grid
#
# - subplots
#
#
# ##[사용법]1. subplot(nrows, ncols, index)
# - nrows : 행의 수
# - nclos : 열의 수
# - index : 1부터 시작하고, 순서는 위부터 오른쪽으로 위쪽에서 아래쪽 방향으로 설정
# subplot(1,2,1) , subplot(121)

# %% [markdown]
# ##[실습]7.subplot을 이용하여 여러개의 그래프를 작성하시오.

# %%
#여러 그래프 그리기
#그래프 그리기
x = list(range(1,32))
plt.figure(figsize=(10,6))
plt.subplot(2,2,1) # 2행 2열의 1번째
plt.plot(x,temp, 'go--')
plt.title('기본그래프')
plt.subplot(2,2,2) # 2행 2열의 1번째
plt.scatter(x,temp)
plt.title('기본그래프')
plt.subplot(2,2,3) # 2행 2열의 1번째
plt.bar(x,temp)
plt.title('기본그래프')
#나머지 그래프 설정 하시오.
plt.subplot(2,2,4) # 2행 2열의 1번째
plt.barh(x,temp)
plt.title('기본그래프')
# Out:
# Text(0.5, 1.0, '기본그래프')

# %% [markdown]
# ##[사용법]2. Figure.subplot(nrows, ncols, index)
# mabplotlib 에서 add_subplot으로 그래프를 그릴 때 두가지를 알아야 합니다.
#
# - Figure : 그래프가 그려질 화면
# - subplot : 그래프

# %% [markdown]
# ##[실습]8.add_subplot을 이용하여 여러개의 그래프를 작성하시오.
# ```
# #figure 만들기
# fig=plt.figure()
#
# #그래프 틀 만들기
# ax1=fig.add_subplot(2,2,1)
# ax2=fig.add_subplot(2,2,2)
# ax3=fig.add_subplot(2,2,3)
# ax4=fig.add_subplot(2,2,4)
#
# #그래프 내용 넣기
# ax1.plot(np.linspace(0,100,20),np.linspace(0,100,20)**2, marker='o', markersize=2, markeredgecolor='r')
# ax2.hist(np.random.randn(500), bins=30, color='b', alpha=0.5)
# ax3.bar([1,3,5,7],np.array([1,2,3,4]),color='r')
# ax4.boxplot(np.random.randn(500,5))
#
# plt.show()
# ```

# %%
#figure 하나를 만들고 그래프 네개를 그려보자
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10, 6))
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)


ax1.plot(np.linspace(0,100,20),np.linspace(0,100,20)**2, marker='o', markersize=2, markeredgecolor='r')
ax2.hist(np.random.randn(500), bins=30, color='b', alpha=0.5)
ax3.bar([1,3,5,7],np.array([1,2,3,4]),color='r')
ax4.boxplot(np.random.randn(500,5))

plt.show()

# %%
#여러 그래프 그리기 방법2

fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

ax1.plot(temp, 'go--')
ax1.set_title('3월 기온1')

ax2.plot(temp, 'bx')
ax2.set_title('3월 기온2')

ax3.plot(temp, 'r+-.')
ax3.set_xlabel('일자')
# Out:
# Text(0.5, 0, '일자')

# %% [markdown]
# ##[실습]9. 아래 세개의 리스트를 한 화면에 작성하는 혼합 그래프를 작성하시오.

# %%
#혼합그래프를 그려보자.
avg = [4.5,6.6,10.5,13.4,19.3,21.1,24.3,27,23.1,18.6,13,7]
min = [-4.4,-4.2,0.5,2.1,11,15.5,19.8,20.3,15.8,10.4,2,-2.8]
max = [13.7,16.5,21,23.4,30.1,29.7,30.9,35,30.5,28.8,24,16.6]

x = list(range(1, len(avg)+1))
# 혼합 그래프 작성
plt.figure(figsize=(10, 6))
plt.plot(x, avg, label='평균')
plt.plot(x, min, label='최소')
plt.plot(x, max, label='최대')
plt.legend()
plt.title('2023년 기온변화')
plt.xlabel('월')
plt.ylabel('기온')
# Out:
# Text(0, 0.5, '기온')

# %% [markdown]
# ###[해결]1. 선 그래프(Line Graph) 그리기
# 문제:
# 다음 데이터를 이용해 선 그래프를 그리세요.
#
# x축: [1, 2, 3, 4, 5]
# y축: [2, 4, 6, 8, 10]

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.show()

# %% [markdown]
# 2. 막대 그래프(Bar Graph) 그리기
# 문제:
# 다음 데이터를 사용하여 막대 그래프를 그리세요.
#
# 카테고리: ['A', 'B', 'C', 'D']
# 값: [10, 15, 7, 20]

# %%
categories = ['A', 'B', 'C', 'D']
values = [10, 15, 7, 20]

plt.bar(categories, values)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# 3. 히스토그램(Histogram) 그리기 :
#  히스토그램 그래프는 데이터의 분포를 시각적으로 확인할 수 있는 그래프이다. 다음 데이터를 사용하여 히스토그램을 그리시오..
#
# 데이터: [1, 2, 2, 3, 3, 3, 4, 4, 5]

# %%
data = [1, 2, 2, 3, 3, 3, 4, 4, 5]

plt.hist(data)
# Out:
# (array([1., 0., 2., 0., 0., 3., 0., 2., 0., 1.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ###[해결]4. 산점도(Scatter Plot) 그리기
# 다음 데이터를 이용해 산점도를 그리시오.
# x축: [5, 7, 8, 7, 2, 17, 2, 9, 4, 11]
# y축: [99, 86, 87, 88, 100, 86, 103, 87, 94, 78]

# %%
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11]
y = [99, 86, 87, 88, 100, 86, 103, 87, 94, 78]

plt.scatter(x, y)

# %% [markdown]
# ###[해결] 5. 파이 차트(Pie Chart) 그리기
#
# ###다음 데이터를 이용해 파이 차트를 그리세요.
#
# 레이블: ['Python', 'Java', 'C++', 'JavaScript']
# 값: [45, 25, 15, 15]

# %%
labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [45, 25, 15, 15]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c7ec8fbb2e0>,
# ...
#  [Text(0.17207795223283864, 1.086457168210212, 'Python'),
#   Text(-0.9801072140121813, -0.49938947630209485, 'Java'),
#   Text(0.17207785051137656, -1.086457184321308, 'C++'),
#   Text(0.9801071672559598, -0.4993895680663526, 'JavaScript')])

# %% [markdown]
# [해결] 1. 선형 함수 그래프
# y = 2x + 1이라는 선형 함수를 0부터 10까지의 x값에 대해 그래프로 그리세요.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)  # 0에서 10까지 100개의 점 생성
y = 2 * x + 1

plt.plot(x, y)

# %% [markdown]
# [해결]2. 사인 함수 그래프
#
# y = cos(x)의 그래프를 0부터 2π까지 그리세요.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 100)
y = np.cos(x)
plt.plot(x, y)
